# %%
from utils import inaturqalistScrapper

# %% [markdown]
# What to get:
# 1. setothosea asigna
# 2. setora nitens
# 3. Darna trima
# 4. Parasa lepida

# %%
inaturqalistScrapper("setothosea_asigna", taxon_id=636458)
# Out:
# Fetching page 1...
# Fetched 115 observations.
# Fetching page 2...
# Scrapped 172 number of image links
# ...

# %%
inaturqalistScrapper("setora_nitens", taxon_id=320752)
# Out:
# Fetching page 1...
# Fetched 200 observations.
# Fetching page 2...
# Fetched 200 observations.
# Fetching page 3...
# Fetched 200 observations.
# Fetching page 4...
# Fetched 200 observations.
# Fetching page 5...
# Fetched 198 observations.
# Fetching page 6...
# Scrapped 1482 number of image links
# ...

# %%
inaturqalistScrapper("Darna_trima", taxon_id=500675)
# Out:
# Fetching page 1...
# Fetched 200 observations.
# Fetching page 2...
# Fetched 200 observations.
# Fetching page 3...
# Fetched 200 observations.
# Fetching page 4...
# Fetched 191 observations.
# Fetching page 5...
# Scrapped 1363 number of image links
# ...
# Error downloading https://inaturalist-open-data.s3.amazonaws.com/photos/11923651/original.jpg: HTTPSConnectionPool(host='inaturalist-open-data.s3.amazonaws.com', port=443): Read timed out. (read timeout=10)
# Error downloading https://inaturalist-open-data.s3.amazonaws.com/photos/11923651/original.jpg: HTTPSConnectionPool(host='inaturalist-open-data.s3.amazonaws.com', port=443): Max retries exceeded with url: /photos/11923651/original.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000027FB3007610>: Failed to resolve 'inaturalist-open-data.s3.amazonaws.com' ([Errno 11001] getaddrinfo failed)"))
# ...

# %%
inaturqalistScrapper("Darna_trima NEW", taxon_id=243617)

# %%
inaturqalistScrapper("Parasa_lepida", taxon_id=1292389)
# Out:
# Fetching page 1...
# Fetched 200 observations.
# Fetching page 2...
# Fetched 200 observations.
# Fetching page 3...
# Fetched 200 observations.
# Fetching page 4...
# Fetched 200 observations.
# Fetching page 5...
# Fetched 200 observations.
# Scrapped 1704 number of image links
# ...
